# %% [markdown]
# <h1> PCA </h1>

# %%
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
digits = datasets.load_digits()
# digits

# %%
X = digits.data
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
X.shape
# Out:
# (1797, 64)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_data = pca.fit_transform(X_scaled)

# %%
pca_data
# Out:
# array([[-1.91421366, -0.95450157],
#        [-0.58898033,  0.9246358 ],
#        [-1.30203906, -0.31718883],
#        ...,
#        [-1.02259599, -0.14791087],
#        [-1.07605522, -0.38090625],
#        [ 1.25770233, -2.22759088]])

# %%
plt.set_cmap('tab10')

fig, ax = plt.subplots()
scatter = ax.scatter(pca_data[:, 0], pca_data[:, 1], c=digits.target)

legend = ax.legend(*scatter.legend_elements(), loc='lower left')
ax.add_artist(legend)

plt.show()
plt.close()

# %% [markdown]
# <hr>

# %% [markdown]
# <h1> T-SNE:- </h1>

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE()

X_embedded = tsne.fit_transform(X_scaled)

# %%
X_embedded
# Out:
# array([[-39.218754 , -31.267836 ],
#        [-15.25776  ,  -2.5319567],
#        [  5.922397 , -14.637942 ],
#        ...,
#        [  2.1472971,  -4.915599 ],
#        [ 36.72832  ,  16.239426 ],
#        [  7.119093 ,  -5.94659  ]], dtype=float32)

# %%
plt.set_cmap('tab10')

fig,ax = plt.subplots()
scatter = ax.scatter(X_embedded[:, 0], X_embedded[:,1], c=digits.target)

legend = ax.legend(*scatter.legend_elements(), loc= 'lower left')
ax.add_artist(legend)

plt.show()
plt.close()

# %% [markdown]
# <hr>

# %% [markdown]
# <h1> UMAP:- </h1>

# %%
import umap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import umap
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\umap\__init__.py:2
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       4 try:
#       5     with catch_warnings():
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\umap\umap_.py:29
#      27 from scipy.sparse import tril as sparse_tril, triu as sparse_triu
#      28 import scipy.sparse.csgraph
# ---> 29 import numba
#      31 import umap.distances as dist
#      33 import umap.sparse as sparse
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 0):
#      43     msg = (f"Numba needs NumPy 2.0 or less. Got NumPy "
#      44            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.0 or less. Got NumPy 2.1.
