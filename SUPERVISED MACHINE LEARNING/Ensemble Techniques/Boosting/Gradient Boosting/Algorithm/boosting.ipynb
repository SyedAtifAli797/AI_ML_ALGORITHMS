# %%
import pickle

# %%
with open('X_train.pickle', 'rb') as file:
    X_train = pickle.load(file)

with open('X_test.pickle', 'rb') as file:
    X_test = pickle.load(file)

with open('Y_train.pickle', 'rb') as file:
    y_train = pickle.load(file)

with open('Y_test.pickle', 'rb') as file:
    y_test = pickle.load(file)

# %%
X_train.shape, X_test.shape
# Out:
# ((15768, 8), (3943, 8))

# %%
y_train.shape, y_test.shape
# Out:
# ((15768,), (3943,))

# %%
X_train[:5]
# Out:
# array([[2213.87987643,  973.92168256, 2345.63183399,  439.47650119,
#         3104.62257134, 2053.53486442, 2769.46116897, 1490.38393338],
#        [ 944.69268874,  197.24696644, 2114.59859144, 1277.64257707,
#         2925.76684493, 2934.17140951, 3320.24381504, 2655.53995613],
#        [ 614.54891514,  190.64067951, 1552.58325193,  268.3461327 ,
#         3425.33651064, 3342.22772202, 3482.49054225, 3277.04973434],
#        [ 461.60097357,  148.411723  ,  614.72982172,   80.59414496,
#           40.98576433,  185.21401831,   44.82319912,  238.79538299],
#        [ 226.98111849,  322.39882662, 1371.25021218,  239.88962711,
#         3771.01352061, 3805.12487902, 3589.18488256, 3463.40565552]])

# %%
y_train[:5]
# Out:
# array([ 1,  1, 19, 15,  3])

# %%
X_test[:5]
# Out:
# array([[  14.54164028,   57.88454981,   33.15518826,   89.82626047,
#          411.88023943,  129.36992612,  325.55419398,   86.63749601],
#        [ 273.10261471, 1023.24916381, 1429.788445  ,  681.05279266,
#         3030.39061037, 2611.60255564, 1442.27191334, 2334.30135319],
#        [ 420.80745667,  288.54459413,  323.97082905,  337.61444185,
#         3020.63663403, 1569.29583951, 2840.99420335, 2960.13742065],
#        [  10.56407052,   24.08557299,   14.66123767,    7.78512363,
#           43.70749411,   43.68101643,   43.30907655,   39.23775323],
#        [ 479.881789  ,   97.38152432,   17.54248887,    8.18390398,
#           53.56560543,  118.06199218,   63.65495015,   58.5735492 ]])

# %%
y_test[:5]
# Out:
# array([14,  8,  3, 12, 10])

# %% [markdown]
# # SIMPLE MODEL BUILDING - GRADIENTBOOSTINGCLASSIFIER:-

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators=150, max_depth=2, loss='log_loss')

# %%
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=2, n_estimators=150)

# %%
print(f'Trainig Score : {gbc.score(X_train, y_train)}')
print(f'Test Score : {gbc.score(X_test, y_test)}')
# Out:
# Trainig Score : 0.9553526128868595
# Test Score : 0.9152929241694141

# %% [markdown]
# # COMPARISON BETWEEN DT, RF AND GBDT:-

# %% [markdown]
# ### 1. Decision Tree:-

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth' : [3,5,7,10,15],
    'max_leaf_nodes' : [20,40,60]
}

# %%
model1 = DecisionTreeClassifier()

# %%
clf = GridSearchCV(model1, params, scoring='accuracy', cv=5)

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [3, 5, 7, 10, 15],
#                          'max_leaf_nodes': [20, 40, 60]},
#              scoring='accuracy')

# %%
print(clf.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=15, max_leaf_nodes=60)

# %%
tree_clf = DecisionTreeClassifier(max_depth=15, max_leaf_nodes=60)

# %%
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, max_leaf_nodes=60)

# %%
print(f'Training Accuracy: {tree_clf.score(X_train, y_train)}')
print(f'Test Accuracy: {tree_clf.score(X_test, y_test)}')
# Out:
# Training Accuracy: 0.8223617453069508
# Test Accuracy: 0.8125792543748415

# %% [markdown]
# ### 2. Random Forest:-

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {
    "n_estimators": [10,25,50,100,150,200],
    "max_depth" : [3, 5, 10, 15, 20],
    "max_leaf_nodes" : [20, 40, 80]
}

# %%
model2 = RandomForestClassifier(n_jobs = -1)

# %%
clf = RandomizedSearchCV(model2, params, scoring = "accuracy", cv=3, n_jobs = -1, verbose = 1)

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1,
#                    param_distributions={'max_depth': [3, 5, 10, 15, 20],
#                                         'max_leaf_nodes': [20, 40, 80],
#                                         'n_estimators': [10, 25, 50, 100, 150,
#                                                          200]},
#                    scoring='accuracy', verbose=1)

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([4.71239352, 1.14769157, 0.56077576, 3.8440702 , 3.45310903,
#         5.52927256, 3.40277624, 3.61344679, 1.00404096, 1.78314471]),
#  'std_fit_time': array([0.45745449, 0.7908247 , 0.21672366, 0.0721773 , 0.67754673,
#         0.26843118, 0.62722045, 0.20444399, 0.13785893, 0.00870475]),
#  'mean_score_time': array([0.42878215, 0.65063326, 0.07274397, 0.30847661, 0.82206066,
#         1.31702995, 0.45693668, 0.90040763, 0.56382918, 0.10527253]),
#  'std_score_time': array([0.08196461, 0.37467243, 0.01401568, 0.02656724, 0.69500463,
#         0.68465511, 0.19926372, 0.40458454, 0.23578006, 0.08921746]),
#  'param_n_estimators': masked_array(data=[150, 10, 10, 150, 100, 200, 100, 200, 10, 50],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'param_max_leaf_nodes': masked_array(data=[80, 40, 80, 40, 20, 20, 40, 40, 20, 20],
# ...

# %%
res = clf.cv_results_

for i in range(len(res["params"])):
    print(f"Parameters:{res['params'][i]} Mean_score: {res['mean_test_score'][i]} Rank: {res['rank_test_score'][i]}")
# Out:
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 80, 'max_depth': 10} Mean_score: 0.882546930492136 Rank: 1
# Parameters:{'n_estimators': 10, 'max_leaf_nodes': 40, 'max_depth': 3} Mean_score: 0.5611998985286656 Rank: 10
# Parameters:{'n_estimators': 10, 'max_leaf_nodes': 80, 'max_depth': 5} Mean_score: 0.7236808726534752 Rank: 8
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 40, 'max_depth': 5} Mean_score: 0.7696600710299341 Rank: 7
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 20, 'max_depth': 10} Mean_score: 0.7994672754946728 Rank: 4
# Parameters:{'n_estimators': 200, 'max_leaf_nodes': 20, 'max_depth': 15} Mean_score: 0.8013698630136986 Rank: 3
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 40, 'max_depth': 15} Mean_score: 0.8522957889396245 Rank: 2
# Parameters:{'n_estimators': 200, 'max_leaf_nodes': 40, 'max_depth': 5} Mean_score: 0.7700405885337392 Rank: 6
# ...

# %%
print(clf.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=10, max_leaf_nodes=80, n_estimators=150,
#                        n_jobs=-1)

# %%
rf_clf = clf.best_estimator_

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_leaf_nodes=80, n_estimators=150,
#                        n_jobs=-1)

# %%
print(f"Training Accuracy: {rf_clf.score(X_train, y_train)}")
print(f"Test Accuracy: {rf_clf.score(X_test, y_test)}")
# Out:
# Training Accuracy: 0.9022704211060375
# Test Accuracy: 0.8858737002282526

# %% [markdown]
# ### 3. Gradient Boosted Decision Trees:-

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {
    "n_estimators": [50,100,150,200],
    "max_depth" : [3, 4, 5, 7],
    "max_leaf_nodes" : [20, 40, 80],
    "learning_rate": [0.1, 0.2, 0.3]
}

# %%
model3 = GradientBoostingClassifier()

# %%
clf = RandomizedSearchCV(model3, params, scoring = "accuracy", cv=3, n_jobs = -1, verbose = 1)

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=GradientBoostingClassifier(), n_jobs=-1,
#                    param_distributions={'learning_rate': [0.1, 0.2, 0.3],
#                                         'max_depth': [3, 4, 5, 7],
#                                         'max_leaf_nodes': [20, 40, 80],
#                                         'n_estimators': [50, 100, 150, 200]},
#                    scoring='accuracy', verbose=1)

# %%
print(f"Training Accuracy: {clf.score(X_train, y_train)}")
print(f"Test Accuracy: {clf.score(X_test, y_test)}")
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 0.9713416180573168
